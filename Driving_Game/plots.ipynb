# %%
from plotting.tools import *

# %%
plot_fitness_evolution_parameter('paillon-config-partial-direct')

# %%
plot_fitness_evolution_parameter('paillon-config-population')

# %%
plot_fitness_diff_species_from_csv('test')
