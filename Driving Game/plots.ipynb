# %%
from plotting.tools import *

# %%
# Plot the final fitness for different values of the parameter 'config-partial-direct'
hist_final_fitness_parameter('paillon-config-partial-direct')

# %%
# Plotting the final fitness for different population sizes
hist_final_fitness_parameter('paillon-config-population')

# %%
# Fitness of different species over generations for single map training
plot_fitness_diff_species_from_csv('paillon_final_final_v2')

# %%
# Fitness of different species over generations for randomized (or not) training
plot_best_fitness_from_csv('paillon_final_final_v2', 'red', linestyle='-', label='Single map training')
plot_best_fitness_from_csv('long_run_prob_change_02', 'purple', linestyle='-', label='Slowly randomized training')
plot_best_fitness_from_csv('long_run_prob_change_1', 'navy', linestyle='-', label='Fully randomized training')
plt.xlim(0, 90)
plt.fill_between([0, 90], 12, 23, color='gray', alpha=0.3)
